# %%
# %load_ext autoreload
# %autoreload 2

import keras
from keras.models import load_model

# from data_loader import get_FMNIST, get_cifar10
from visualizer import compare_FMNIST, compare_CIFAR
from ae_models import get_CAE_FMNIST_Model, get_CAE_CIFAR_Model,  get_AE_FMNIST_model, get_AE_CIFAR_model,get_VCAE_FMNST_model 
from ae_models import get_VCAE_CIFAR_model, train_model,train_torch_model, torch_predict, load_torch_model

# Data loading
from data_loader import get_cifar10, get_FMNIST, get_CIFAR_torch,get_FMNST_torch

from metrics import print_metrics

import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
(x_train, x_test, labels_test) = get_FMNIST()
(x_train_c, x_test_c, labels_test_c) = get_cifar10()

# %%
model = get_CAE_FMNIST_Model()
train_model(model, 'cae_fmnist', x_train, x_test)
# Out:
# Epoch 1/40
#   1/469 ━━━━━━━━━━━━━━━━━━━━ 12:32 2s/step - loss: 0.1695
# 2024-04-07 13:05:57.782142: E tensorflow/core/util/util.cc:131] oneDNN supports DT_INT32 only on platforms with AVX-512. Falling back to the default Eigen-based implementation if present.
# 297/469 ━━━━━━━━━━━━━━━━━━━━ 16s 95ms/step - loss: 0.0638
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[81], line 2
#       1 model = get_CAE_FMNIST_Model()
# ----> 2 train_model(model, 'cae_fmnist', x_train, x_test)
#
# File ~/Documents/git/MLaBP_P5/ae_models.py:177, in train_model(model, model_name, x_train, validation)
#     169 cp_callback = ModelCheckpoint(filepath=checkpoint_path,
#     170                             save_weights_only=False, # Save entire model
#     171                             verbose=1,
#     172                             save_best_only=False,
# ...

# %%
model2 = get_CAE_CIFAR_Model()
train_model(model2, 'cae_cifar', x_train_c, x_test_c)
# Out:
# Epoch 1/40
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0375
# Epoch 1: saving model to ./training_checkpoints/cae_cifar/001-0.0237.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 51s 127ms/step - loss: 0.0375 - val_loss: 0.0237
# Epoch 2/40
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0229
# Epoch 2: saving model to ./training_checkpoints/cae_cifar/002-0.0224.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 47s 120ms/step - loss: 0.0229 - val_loss: 0.0224
# Epoch 3/40
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.0220
# Epoch 3: saving model to ./training_checkpoints/cae_cifar/003-0.0220.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 51s 130ms/step - loss: 0.0220 - val_loss: 0.0220
# Epoch 4/40
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0218
# Epoch 4: saving model to ./training_checkpoints/cae_cifar/004-0.0219.keras
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 57s 145ms/step - loss: 0.0218 - val_loss: 0.0219
# Epoch 5/40
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 0.0217
# ...

# %%
model3 = get_AE_FMNIST_model()
train_model(model3, 'ae_fmnist', x_train.reshape(-1,784), x_test.reshape(-1,784))
# Out:
# Model: "functional_27"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_9 (InputLayer)      │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 300)            │       235,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_27 (Dense)                │ (None, 128)            │        38,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 12)             │         1,548 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 275,576 (1.05 MB)
#  Trainable params: 275,576 (1.05 MB)
# ...

# %%
model4 = get_AE_CIFAR_model()
train_model(model4, 'ae_cifar', x_train_c.reshape(-1,3072), x_test_c.reshape(-1,3072))
# Out:
# Model: "functional_33"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_11 (InputLayer)     │ (None, 3072)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_32 (Dense)                │ (None, 300)            │       921,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_33 (Dense)                │ (None, 128)            │        38,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_34 (Dense)                │ (None, 12)             │         1,548 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 961,976 (3.67 MB)
#  Trainable params: 961,976 (3.67 MB)
# ...

# %%
train_dataloader_cifar,test_dataloader_cifar= get_CIFAR_torch()
train_dataloader_fmnist,test_dataloader_fmnist= get_FMNST_torch()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
model5=get_VCAE_CIFAR_model()
train_torch_model(model5, 'vcae_cifar', train_dataloader_cifar)
# Out:
# epoch [total loss: 9959.036, mse loss: 7904.624]: 100%|██████████| 40/40 [1:16:09<00:00, 114.23s/it]
# VariationalAutoencoder(
#   (encoder): Encoder_cifar(
#     (conv1): Conv2d(3, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv2): Conv2d(40, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv3): Conv2d(80, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#     (fc_mu): Linear(in_features=10240, out_features=12, bias=True)
#     (fc_logvar): Linear(in_features=10240, out_features=12, bias=True)
#   )
#   (decoder): Decoder_cifar(
#     (fc): Linear(in_features=12, out_features=10240, bias=True)
#     (reshape): Unflatten(dim=1, unflattened_size=(160, 8, 8))
# ...

# %%
model6=get_VCAE_FMNST_model()
train_torch_model(model6, 'vcae_fmnist', train_dataloader_fmnist,True)
# Out:
# epoch [total loss: 2951.561, mse loss: 1858.525]: 100%|██████████| 40/40 [2:10:25<00:00, 195.64s/it]
# VariationalAutoencoder_FMNIST(
#   (encoder): Encoder_fmnist(
#     (conv1): Conv2d(1, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv2): Conv2d(40, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv3): Conv2d(80, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#     (fc_mu): Linear(in_features=7840, out_features=12, bias=True)
#     (fc_logvar): Linear(in_features=7840, out_features=12, bias=True)
#   )
#   (decoder): Decoder_fmnist(
#     (fc): Linear(in_features=12, out_features=7840, bias=True)
#     (reshape): Unflatten(dim=1, unflattened_size=(160, 7, 7))
# ...

# %%
from keras.models import load_model
#load the latest models
epoch_load=40

# training_checkpoints/ae_cifar/040-0.0202.keras
# Specify the path to the .keras file
directory = "./training_checkpoints"
model_str='cae_fmnist'
model2_Str='cae_cifar'
model3_str='ae_fmnist'
model4_str='ae_cifar'
model5_str='vcae_cifar'
model6_str='vcae_fmnist'


# Load the model
model = load_model("training_checkpoints/cae_fmnist/040-0.0119.keras")
model2 = load_model("training_checkpoints/cae_cifar/040-0.0215.keras")
# model3= load_model("training_checkpoints/ae_fmnist/040-0.0140.keras")
# model4= load_model("training_checkpoints/ae_cifar/040-0.0202.keras")
model6= load_torch_model("training_checkpoints/vae_epoch_40_vcae_fmnist.pth",fmnist=True)
model5= load_torch_model("training_checkpoints/vae_epoch_40_vcae_cifar.pth")

# %%
compare_FMNIST(x_test, model)
compare_FMNIST(x_test.reshape(-1,784), model3)
compare_FMNIST(x_test.reshape(-1,784), model6,test_dataloader_fmnist)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# test batch [loss: 2572.731]: 100%|██████████| 79/79 [00:11<00:00,  7.01it/s]

# %%
compare_CIFAR(x_test_c, model2)
compare_CIFAR(x_test_c.reshape(-1,3072), model4,)
compare_CIFAR(x_test_c, model5,test_dataloader_cifar)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# test batch [loss: 9398.288]: 100%|██████████| 79/79 [00:12<00:00,  6.40it/s]

# %%
from visualizer import compare_cifar_models, compare_fmnist_models
image_number=20
compare_fmnist_models([(model3, 'Dense', 1), (model, 'Conv', 0),(model6,'Var',0)], x_test[image_number],test_dataloader_fmnist,image_number-3)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# test batch [loss: 2572.731]: 100%|██████████| 79/79 [00:10<00:00,  7.54it/s]

# %%
image_number=13
compare_cifar_models([(model4, 'Dense', 1), (model2, 'Conv', 0),(model5,'Var',0)], x_test_c[image_number],test_dataloader_cifar,image_number-3)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# test batch [loss: 9398.288]: 100%|██████████| 79/79 [00:16<00:00,  4.89it/s]

# %%
import time
import pandas as pd

#CAE FMNIST

start_time = time.time()
pred=model.predict(x_test.reshape(-1,28,28,1))
end_time = time.time()

execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

print_metrics("CAE_FMNIST",x_test,pred)

df = pd.read_csv("losses/cae_fmnist_losses.csv")

df.plot(y=['loss', 'val_loss'], title='CAE FMNIST Loss', legend=False)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
# Execution time: 3.2181308269500732 seconds
# Metrics for CAE_FMNIST:
# MAE score: 0.05314512178301811
# MSE score: 0.011764674447476864

# %%
#AE FMNIST

start_time = time.time()
pred=model3.predict(x_test.reshape(-1,784))
end_time = time.time()

execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")


df = pd.read_csv("losses/ae_fmnist_losses.csv")
print_metrics("AE_FMNIST",x_test,pred)

df.plot(y=['loss', 'val_loss'], title='AE FMNIST Loss', legend=False)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Execution time: 0.6427271366119385 seconds
# Metrics for AE_FMNIST:
# MAE score: 0.05606451630592346
# MSE score: 0.011939196847379208

# %%
start_time = time.time()
pred=torch_predict(model6, test_dataloader_fmnist,fmnist=True)
end_time = time.time()

execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
print_metrics("VCAE_FMNIST",x_test,pred)
# Out:
# test batch [loss: 2572.731]: 100%|██████████| 79/79 [00:11<00:00,  6.80it/s]
# Execution time: 11.627424001693726 seconds
# Metrics for VCAE_FMNIST:
# MAE score: 0.06661612540483475
# MSE score: 0.015362686477601528
# (0.066616125, 0.0153626865)

# %%
#CAE CIFAR
start_time = time.time()
pred=model2.predict(x_test_c.reshape(-1,32,32,3))
    
end_time = time.time()

execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
print_metrics("CAE_Ciphar",x_test_c,pred)
df = pd.read_csv("losses/cae_cifar_losses.csv")

df.plot(y=['loss', 'val_loss'], title='CAE CIFAR Loss', legend=False)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step
# Execution time: 4.166332721710205 seconds
# Metrics for CAE_Ciphar:
# MAE score: 0.10865456610918045
# MSE score: 0.02138501964509487

# %%
#
start_time = time.time()
model4.predict(x_test_c.reshape(-1,3072))
end_time = time.time()

execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

df = pd.read_csv("losses/ae_cifar_losses.csv")
print_metrics("AE_Ciphar",x_test_c,pred)
df.plot(y=['loss', 'val_loss'], title='AE Cifar Loss', legend=False)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Execution time: 1.2389063835144043 seconds
# Metrics for AE_Ciphar:
# MAE score: 0.10865456610918045
# MSE score: 0.02138501964509487

# %%
#VCAE CIFAR
start_time = time.time()
torch_predict(model5, test_dataloader_cifar)
end_time = time.time()
print_metrics("VCAE_Ciphar",x_test,pred)
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# test batch [loss: 9398.288]: 100%|██████████| 79/79 [00:12<00:00,  6.09it/s]
# Execution time: 12.996595859527588 seconds

# %%
from visualizer import plot_all
import torch
import numpy as np

from ae_models import extract_latent

extract_latent(model5, test_dataloader_cifar, fmnist=False).shape
# Out:
# test batch [loss: 9398.288]: 100%|██████████| 79/79 [00:12<00:00,  6.13it/s]
# torch.Size([10000, 12])
